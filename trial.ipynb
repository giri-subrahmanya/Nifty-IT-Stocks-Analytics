# %%
import yfinance as yf

# %%
tickers = [
    "HCLTECH.NS",
    "INFY.NS",
    "TCS.NS",
    "TECHM.NS",
    "WIPRO.NS",
    "^CNXIT",
    "^NSEI",
    "^INDIAVIX"
]

ticker = yf.Ticker('^NSEBANK')

# %%
import yfinance as yf
import pandas as pd

start_date = '2023-03-01'
end_date = '2025-06-16'

tickers = {
    'hcl': 'HCLTECH.NS',
    'infosys': 'INFY.NS',
    'tcs': 'TCS.NS',
    'techM': 'TECHM.NS',
    'wipro': 'WIPRO.NS',
    'nifty_it': '^CNXIT',
    'nifty_50': '^NSEI',
}

symbols = list(tickers.values())
df = yf.download(symbols, start=start_date, end=end_date, auto_adjust=False, progress=False, group_by='ticker')

# %%
df.to_csv('a/abc.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df.to_csv('a/abc.csv')
#
# File ~/Nifty-IT-Stocks-Analytics/venv/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
df['HCLTECH.NS']
# Out:
# Price              Open         High          Low        Close    Adj Close  \
# Date
# 2023-03-01  1077.349976  1104.000000  1077.349976  1101.099976  1007.913330
# 2023-03-02  1090.300049  1117.000000  1090.300049  1105.949951  1012.352783
# 2023-03-03  1115.000000  1129.699951  1111.050049  1119.000000  1024.298584
# 2023-03-06  1129.000000  1148.000000  1123.300049  1126.699951  1031.346436
# 2023-03-08  1112.000000  1124.000000  1107.300049  1120.650024  1025.808838
# ...                 ...          ...          ...          ...          ...
# 2025-06-09  1648.000000  1658.000000  1639.000000  1648.300049  1648.300049
# 2025-06-10  1653.300049  1684.900024  1649.000000  1668.099976  1668.099976
# 2025-06-11  1676.000000  1725.400024  1666.000000  1721.900024  1721.900024
# 2025-06-12  1725.000000  1726.000000  1695.000000  1701.199951  1701.199951
# 2025-06-13  1666.000000  1711.000000  1664.599976  1695.300049  1695.300049
#
# Price        Volume
# Date
# 2023-03-01  1655100
# ...

# %%
df.xs()
